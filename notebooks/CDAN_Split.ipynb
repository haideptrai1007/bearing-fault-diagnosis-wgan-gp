# %%
import torch

# %%
cwru_test = torch.load(r"D:\Capstone\dataset\processed\CNN\CWRU\Scalogram\test.pt")
cwru_val = torch.load(r"D:\Capstone\dataset\processed\CNN\CWRU\Scalogram\val.pt")

# %%
target_data = torch.concat([cwru_test['data'], cwru_val['data']], dim=0)
target_label = torch.concat([cwru_test['label'], cwru_val['label']], dim=0)

# %%
target = {"data": target_data, "label": target_label}

# %%
root_path = r"D:\Capstone\dataset\processed\CDAN\CWRU\Scalogram\target.pt"

# %%
torch.save(target, root_path)
