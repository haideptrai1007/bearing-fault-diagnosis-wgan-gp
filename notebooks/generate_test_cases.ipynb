# %%
import os
os.chdir('..')

# %%
from src.data.test_case_generator import get_mat, normal_fault1_fault2, normal_all_fault

# %% [markdown]
# # Get Signals

# %%
normal = get_mat(r"D:\Capstone\dataset\test_cases\Normal", normal=True)
outer_race = get_mat(r"D:\Capstone\dataset\test_cases\OR")
inner_race = get_mat(r"D:\Capstone\dataset\test_cases\IR")
ball = get_mat(r"D:\Capstone\dataset\test_cases\B")

# %% [markdown]
# # Test Case

# %% [markdown]
# ### Normal - Outer Race

# %%
normal_fault1_fault2(normal=normal,
                   normal_id=0,
                   normal_label=0,
                   fault1=outer_race,
                   fault2=outer_race,
                   fault_id_1=0,
                   fault_id_2=1,
                   fault_label1=1,
                   fault_label2=1,
                   root_path=r"D:\Capstone\dataset\test_cases\Norm_Outer")

# %% [markdown]
# ### Normal - Inner Race

# %%
normal_fault1_fault2(normal=normal,
                   normal_id=1,
                   normal_label=0,
                   fault1=inner_race,
                   fault2=inner_race,
                   fault_id_1=0,
                   fault_id_2=1,
                   fault_label1=2,
                   fault_label2=2,
                   root_path=r"D:\Capstone\dataset\test_cases\Norm_Inner")

# %% [markdown]
# ### Normal - Ball

# %%
normal_fault1_fault2(normal=normal,
                   normal_id=2,
                   normal_label=0,
                   fault1=ball,
                   fault2=ball,
                   fault_id_1=0,
                   fault_id_2=1,
                   fault_label1=3,
                   fault_label2=3,
                   root_path=r"D:\Capstone\dataset\test_cases\Norm_Ball")

# %% [markdown]
# ### Normal - OR - IR

# %%
normal_fault1_fault2(normal=normal,
                   normal_id=0,
                   normal_label=0,
                   fault1=outer_race,
                   fault2=inner_race,
                   fault_id_1=2,
                   fault_id_2=2,
                   fault_label1=1,
                   fault_label2=2,
                   root_path=r"D:\Capstone\dataset\test_cases\Norm_Outer_Inner")

# %% [markdown]
# ### Normal - OR - B

# %%
normal_fault1_fault2(normal=normal,
                   normal_id=0,
                   normal_label=0,
                   fault1=outer_race,
                   fault2=ball,
                   fault_id_1=3,
                   fault_id_2=3,
                   fault_label1=1,
                   fault_label2=3,
                   root_path=r"D:\Capstone\dataset\test_cases\Norm_Outer_Ball")

# %% [markdown]
# ### Normal - IR - B

# %%
normal_fault1_fault2(normal=normal,
                   normal_id=0,
                   normal_label=0,
                   fault1=inner_race,
                   fault2=ball,
                   fault_id_1=4,
                   fault_id_2=4,
                   fault_label1=2,
                   fault_label2=3,
                   root_path=r"D:\Capstone\dataset\test_cases\Norm_Inner_Ball")

# %% [markdown]
# ### Normal - OR - IR - B

# %%
normal_all_fault(normal=normal,
                   normal_id=0,
                   normal_label=0,
                   fault1=outer_race,
                   fault2=inner_race,
                   fault3=ball,
                   fault_id_1=5,
                   fault_id_2=5,
                   fault_id_3=5,
                   fault_label1=1,
                   fault_label2=2,
                   fault_label3=3,
                   root_path=r"D:\Capstone\dataset\test_cases\Norm_Outer_Inner_Ball")
